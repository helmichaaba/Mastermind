# %%
#Global variables
code_dict={1:'RED', 2:'GREEN', 3:'BLUE', 4:'BLACK', 5:'WHITE', 6:'PURPLE'}
codelist=[]
playerlist= []
playerlist2= []
usersrounds = int(input('How many rounds to be played ?: '))
if usersrounds%2 != 0:
    usersrounds = int(input('please input an even number: '))
#Function random code generator
def code_generator():
    import random
    code_keys=list(code_dict.keys())
    i=1
    while i<5:
        codelist.append(random.choice(code_keys))
        i+=1
    print(codelist)
    
    

#Function player attempt
def playerattempt():

    reflist = [1, 2, 3, 4, 5, 6]
    i= 1

    while i<5:
        userinput = int(input("Please key in 1 for RED, or 2 for GREEN, or 3 for BLUE, or 4 for BLACK, or 5 for WHITE, or 6 for PURPLE: "))
    
        if userinput not in reflist:
            userinput = int(input("Please make sure your input is either one of the 6 authorized integers!: "))
    
        playerlist.append(userinput)
        
        i +=1
        
    for item in playerlist:
        playerlist2.append(code_dict[item]) 
        
    print("Attempt #", playerloop, "is: ", playerlist2)
    
    
#Function compare
def compare():
    results=[]
    for i in range(len(playerlist)):
        if playerlist[i]==codelist[i]:
            results.append('exact match')
        elif playerlist[i] in codelist and playerlist[i]!=codelist[i]:
            results.append('near match')
        else:
            results.append('no match')
    print(results)

#Initiate player attempts
playerloop = 1

#Max number of player attempts
maxloop = usersrounds


code_generator()            


#Maxloop control    
while playerloop <= maxloop :
    playerattempt()
    compare()
    if playerlist == codelist:
        print('You are a winner: bravo !')
        break
    
    playerloop +=1
    playerlist = []
    playerlist2 = []
# Out:
# How many rounds to be played ?: 6
# [5, 4, 4, 5]
# Please key in 1 for RED, or 2 for GREEN, or 3 for BLUE, or 4 for BLACK, or 5 for WHITE, or 6 for PURPLE: 1
# Please key in 1 for RED, or 2 for GREEN, or 3 for BLUE, or 4 for BLACK, or 5 for WHITE, or 6 for PURPLE: 2
# Please key in 1 for RED, or 2 for GREEN, or 3 for BLUE, or 4 for BLACK, or 5 for WHITE, or 6 for PURPLE: 3
# Please key in 1 for RED, or 2 for GREEN, or 3 for BLUE, or 4 for BLACK, or 5 for WHITE, or 6 for PURPLE: 4
# Attempt # 1 is:  ['RED', 'GREEN', 'BLUE', 'BLACK']
# ['no match', 'no match', 'no match', 'near match']
# Please key in 1 for RED, or 2 for GREEN, or 3 for BLUE, or 4 for BLACK, or 5 for WHITE, or 6 for PURPLE: 3
# Please key in 1 for RED, or 2 for GREEN, or 3 for BLUE, or 4 for BLACK, or 5 for WHITE, or 6 for PURPLE: 5
# Please key in 1 for RED, or 2 for GREEN, or 3 for BLUE, or 4 for BLACK, or 5 for WHITE, or 6 for PURPLE: 2
# Please key in 1 for RED, or 2 for GREEN, or 3 for BLUE, or 4 for BLACK, or 5 for WHITE, or 6 for PURPLE: 1
# Attempt # 2 is:  ['BLUE', 'WHITE', 'GREEN', 'RED']
# ['no match', 'near match', 'no match', 'no match']
# Please key in 1 for RED, or 2 for GREEN, or 3 for BLUE, or 4 for BLACK, or 5 for WHITE, or 6 for PURPLE: 6
# Please key in 1 for RED, or 2 for GREEN, or 3 for BLUE, or 4 for BLACK, or 5 for WHITE, or 6 for PURPLE: 4
# Please key in 1 for RED, or 2 for GREEN, or 3 for BLUE, or 4 for BLACK, or 5 for WHITE, or 6 for PURPLE: 3
# Please key in 1 for RED, or 2 for GREEN, or 3 for BLUE, or 4 for BLACK, or 5 for WHITE, or 6 for PURPLE: 1
# Attempt # 3 is:  ['PURPLE', 'BLACK', 'BLUE', 'RED']
# ['no match', 'exact match', 'no match', 'no match']
# Please key in 1 for RED, or 2 for GREEN, or 3 for BLUE, or 4 for BLACK, or 5 for WHITE, or 6 for PURPLE: 5
# Please key in 1 for RED, or 2 for GREEN, or 3 for BLUE, or 4 for BLACK, or 5 for WHITE, or 6 for PURPLE: 3
# Please key in 1 for RED, or 2 for GREEN, or 3 for BLUE, or 4 for BLACK, or 5 for WHITE, or 6 for PURPLE: 1
# Please key in 1 for RED, or 2 for GREEN, or 3 for BLUE, or 4 for BLACK, or 5 for WHITE, or 6 for PURPLE: 4
# Attempt # 4 is:  ['WHITE', 'BLUE', 'RED', 'BLACK']
# ['exact match', 'no match', 'no match', 'near match']
# Please key in 1 for RED, or 2 for GREEN, or 3 for BLUE, or 4 for BLACK, or 5 for WHITE, or 6 for PURPLE: 3
# Please key in 1 for RED, or 2 for GREEN, or 3 for BLUE, or 4 for BLACK, or 5 for WHITE, or 6 for PURPLE: 5
# Please key in 1 for RED, or 2 for GREEN, or 3 for BLUE, or 4 for BLACK, or 5 for WHITE, or 6 for PURPLE: 4
# Please key in 1 for RED, or 2 for GREEN, or 3 for BLUE, or 4 for BLACK, or 5 for WHITE, or 6 for PURPLE: 3
# Attempt # 5 is:  ['BLUE', 'WHITE', 'BLACK', 'BLUE']
# ['no match', 'near match', 'exact match', 'no match']
# Please key in 1 for RED, or 2 for GREEN, or 3 for BLUE, or 4 for BLACK, or 5 for WHITE, or 6 for PURPLE: 3
# Please key in 1 for RED, or 2 for GREEN, or 3 for BLUE, or 4 for BLACK, or 5 for WHITE, or 6 for PURPLE: 2
# Please key in 1 for RED, or 2 for GREEN, or 3 for BLUE, or 4 for BLACK, or 5 for WHITE, or 6 for PURPLE: 1
# Please key in 1 for RED, or 2 for GREEN, or 3 for BLUE, or 4 for BLACK, or 5 for WHITE, or 6 for PURPLE:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/x4/yrc5_3n97xd87b1phrpz_8qr0000gn/T/ipykernel_12331/1075379749.py in <module>
#      65 #Maxloop control
#      66 while playerloop <= maxloop :
# ---> 67     playerattempt()
#      68     compare()
#      69     if playerlist == codelist:
#
# /var/folders/x4/yrc5_3n97xd87b1phrpz_8qr0000gn/T/ipykernel_12331/1075379749.py in playerattempt()
#      26
#      27     while i<5:
# ---> 28         userinput = int(input("Please key in 1 for RED, or 2 for GREEN, or 3 for BLUE, or 4 for BLACK, or 5 for WHITE, or 6 for PURPLE: "))
#      29
#      30         if userinput not in reflist:
#
# ValueError: invalid literal for int() with base 10: ''
