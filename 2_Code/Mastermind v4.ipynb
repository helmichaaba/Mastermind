# %%
#Global variables
code_dict={1:'RED', 2:'GREEN', 3:'BLUE', 4:'BLACK', 5:'WHITE', 6:'PURPLE'}
codelist=[]
playerlist= []
playerlist2= []


#Function random code generator
def code_generator():
    import random
    code_keys=list(code_dict.keys())
    i=1
    while i<5:
        codelist.append(random.choice(code_keys))
        i+=1
    return codelist

#Function player attempt
def playerattempt():

    reflist = [1, 2, 3, 4, 5, 6]
    i= 1
    
    while i<5:
        userinput = int(input("Please choose one coloured pin (1 is RED, 2 is GREEN, 3 is BLUE, 4 is BLACK, 5 is WHITE, 6 is PURPLE):"))
    
        if userinput not in reflist:
            userinput = int(input("Please make sure your input actually is an integer from 1 to 6 !: "))
    
        playerlist.append(userinput)
        
        i +=1
        
    for item in playerlist:
        playerlist2.append(code_dict[item]) 
        
    print(">>> Your attempt #", playerloop+1, "was: ", playerlist2)
    
    
#Function compare
def compare():
    results=[]
    
    for i in range(len(playerlist)):
        if playerlist[i]==codelist[i]:
            results.append('exact match')
        elif playerlist[i] in codelist and playerlist[i]!=codelist[i]:
            results.append('near match')
        else:
            results.append('no match')
    print(">>> Your result is: ", results)

#Initiate player attempts
playerloop = 0

#Max number of player attempts
maxloop = 12

code_generator()            


#Maxloop control    
while playerloop <= maxloop :
    playerattempt()
    compare()
    if playerlist == codelist:
        print('You are a winner: Congrats!')
        break
           
    playerloop +=1
    playerlist = []
    playerlist2 = []
    
    if playerlist != codelist and playerloop == maxloop:
        print("This was your last attempt and you lost: Please try again soon!")
        break
# Out:
# Please choose one coloured pin (1 is RED, 2 is GREEN, 3 is BLUE, 4 is BLACK, 5 is WHITE, 6 is PURPLE):1
# Please choose one coloured pin (1 is RED, 2 is GREEN, 3 is BLUE, 4 is BLACK, 5 is WHITE, 6 is PURPLE):2
# Please choose one coloured pin (1 is RED, 2 is GREEN, 3 is BLUE, 4 is BLACK, 5 is WHITE, 6 is PURPLE):3
# Please choose one coloured pin (1 is RED, 2 is GREEN, 3 is BLUE, 4 is BLACK, 5 is WHITE, 6 is PURPLE):4
# >>> Your attempt # 1 was:  ['RED', 'GREEN', 'BLUE', 'BLACK']
# >>> Your result is:  ['no match', 'near match', 'near match', 'exact match']
